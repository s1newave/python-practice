# %% [markdown]
# # Задание № 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
s1 = pd.Series(data=['1', 2, 3.1, 'hi!', 15, -52, 12.42, 'sb', 10.1, 98], index=range(6, 26, 2))

# %%
s2 = s1[8] + s1[14] - s1.apply(lambda x: isinstance(x, int)).sum()
print(s2)
# Out:
# 13

# %% [markdown]
# # Задание № 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
tr_mcc_code = pd.read_csv("tr_mcc_codes.csv", sep=";")
transactions = pd.read_csv("transactions.csv", nrows=500_000)

# %%
tr_mcc_code.head()
# Out:
#    mcc_code                                    mcc_description
# 0       742                                Ветеринарные услуги
# 1      1711  Генеральные подрядчики по вентиляции, теплосна...
# 2      1731                        Подрядчики по электричеству
# 3      1799  Подрядчики, специализированная торговля — нигд...
# 4      2741           Разнообразные издательства/печатное дело

# %%
transactions.tail()
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type    amount   term_id
# 499995     71186181  411 12:41:25      5814     1110  -3571.01  26021835
# 499996     71186181  411 18:40:49      6011     2010 -15721.41     51586
# 499997     71186181  411 19:08:23      5411     1010 -13877.96    696286
# 499998     71186181  411 19:39:00      5411     1010 -12764.89    698937
# 499999     71186181  411 23:04:00      4814     1030  -3368.87    888910

# %% [markdown]
# # Задание № 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
df = pd.read_csv("transactions.csv")

# %%
(df.sort_values(by="amount", ascending=False)
   .drop_duplicates(["mcc_code", "tr_type"], keep="last")
   .amount
   .median())
# Out:
# -147527.35499999998
